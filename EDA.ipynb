# %% [markdown]
# <a href="https://colab.research.google.com/github/twishanar/healthsys/blob/main/EDA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # US accidents ExploExploratory data analysis

# %% [markdown]
# ## Data source- kaggle contains informatin regarding accidents which can be useful to prevent them.
# ## download data

# %%
pip install opendatasets --upgrade --quiet

# %%
import opendatasets as od
download_url='https://www.kaggle.com/sobhanmoosavi/us-accidents?select=US_Accidents_Dec20_Updated.csv'
od.download(download_url)
# Out:
# Please provide your Kaggle credentials to download this dataset. Learn more: http://bit.ly/kaggle-creds
# Your Kaggle username: twishanarendra
# Your Kaggle Key: ··········
# ...
# 100%|██████████| 290M/290M [00:04<00:00, 64.3MB/s]

# %%
file_name='./us-accidents/US_Accidents_Dec20_Updated.csv'

# %% [markdown]
# ## Data preparation and cleaning
# ### Load the data using pandas,
# ### explore the data and information available,
# ### fill in any missing or incorrect values

# %%
import pandas as pd
df= pd.read_csv(file_name)
df
# Out:
#                 ID  Severity  ... Nautical_Twilight Astronomical_Twilight
# 0              A-1         2  ...               Day                   Day
# 1              A-2         2  ...               Day                   Day
# 2              A-3         2  ...             Night                 Night
# 3              A-4         2  ...               Day                   Day
# 4              A-5         3  ...               Day                   Day
# ...            ...       ...  ...               ...                   ...
# 2906605  A-2906606         2  ...               Day                   Day
# 2906606  A-2906607         2  ...             Night                 Night
# 2906607  A-2906608         2  ...               Day                   Day
# 2906608  A-2906609         2  ...             Night                 Night
# 2906609  A-2906610         2  ...               Day                   Day
#
# [2906610 rows x 47 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2906610 entries, 0 to 2906609
# Data columns (total 47 columns):
#  #   Column                 Dtype
# ---  ------                 -----
#  0   ID                     object
#  1   Severity               int64
#  2   Start_Time             object
#  3   End_Time               object
#  4   Start_Lat              float64
#  5   Start_Lng              float64
#  6   End_Lat                float64
#  7   End_Lng                float64
#  8   Distance(mi)           float64
#  9   Description            object
#  10  Number                 float64
#  11  Street                 object
#  12  Side                   object
#  13  City                   object
#  14  County                 object
#  15  State                  object
#  16  Zipcode                object
#  17  Country                object
#  18  Timezone               object
#  19  Airport_Code           object
#  20  Weather_Timestamp      object
# ...

# %%
df.describe()
# Out:
#            Severity     Start_Lat  ...  Wind_Speed(mph)  Precipitation(in)
# count  2.906610e+06  2.906610e+06  ...     2.599447e+06       1.605284e+06
# mean   2.288649e+00  3.653027e+01  ...     7.818111e+00       1.119459e-02
# std    5.541618e-01  5.013964e+00  ...     5.431171e+00       1.540812e-01
# min    1.000000e+00  2.455527e+01  ...     0.000000e+00       0.000000e+00
# 25%    2.000000e+00  3.366453e+01  ...     4.600000e+00       0.000000e+00
# 50%    2.000000e+00  3.609977e+01  ...     7.000000e+00       0.000000e+00
# 75%    3.000000e+00  4.037505e+01  ...     1.040000e+01       0.000000e+00
# max    4.000000e+00  4.900220e+01  ...     9.840000e+02       2.400000e+01
#
# [8 rows x 14 columns]

# %%
numerics = ['int16', 'int32', 'int64', 'float16', 'float32', 'float64']

numeric_df = df.select_dtypes(include=numerics)
len(numeric_df.columns)
# Out:
# 14

# %%
df.isna().sum()
# Out:
# ID                             0
# Severity                       0
# Start_Time                     0
# End_Time                       0
# Start_Lat                      0
# Start_Lng                      0
# End_Lat                   282821
# End_Lng                   282821
# Distance(mi)                   0
# Description                    0
# Number                   1891672
# Street                         0
# Side                           0
# City                         108
# County                         0
# State                          0
# Zipcode                     1114
# Country                        0
# Timezone                    3430
# Airport_Code                6608
# Weather_Timestamp          46917
# Temperature(F)             67224
# Wind_Chill(F)            1183859
# Humidity(%)                71270
# Pressure(in)               56908
# Visibility(mi)             72078
# Wind_Direction             63474
# Wind_Speed(mph)           307163
# ...

# %% [markdown]
# # finding percentage of missing values per column

# %%
missing_percentages=df.isna().sum().sort_values(ascending= False)/len(df) *100
missing_percentages[missing_percentages !=0].plot(kind='barh')

# %% [markdown]
# # Exploratory Analysis and visualisation
# 1. city
# 2. start time
# 3. start lat and  start long

# %% [markdown]
# ### City

# %%
city=df.City.unique()
len(city)
# Out:
# 11790

# %%
city_by_acc= df.City.value_counts()
city_by_acc
# Out:
# Los Angeles    68411
# Houston        68265
# Charlotte      56176
# Miami          49965
# Dallas         48525
#                ...
# Elkville           1
# Farragut           1
# Rugby              1
# Gatesville         1
# Buckfield          1
# Name: City, Length: 11789, dtype: int64

# %%
city_by_acc[:20]
# Out:
# Los Angeles      68411
# Houston          68265
# Charlotte        56176
# Miami            49965
# Dallas           48525
# Austin           38808
# Raleigh          31355
# Atlanta          29244
# Sacramento       28984
# Orlando          28092
# Nashville        25277
# Baton Rouge      25080
# Minneapolis      22469
# San Diego        22329
# Phoenix          21370
# Oklahoma City    21292
# Portland         19432
# Richmond         18343
# Seattle          17384
# Saint Paul       17266
# Name: City, dtype: int64

# %%
'New York' in df.City or 'NY' in df.State
# Out:
# False

# %%
city_by_acc[:20].plot(kind='barh')

# %%
import seaborn as sns
sns.set_style("darkgrid")
sns.distplot(city_by_acc)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# Most of the cites have less than 2000 accidents as seen in the dist plot

# %%
high_acc_city= city_by_acc[city_by_acc>=1000]
low_acc_city= city_by_acc[city_by_acc<1000]

# %%
len(high_acc_city)/len(city_by_acc)*100
len(low_acc_city)/len(city_by_acc)*100
# Out:
# 95.6484858766647

# %%
sns.distplot(high_acc_city)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.distplot(low_acc_city)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# Since the graph is moving exponenetially, it will be better to visualise a logarithmic plot

# %%
sns.histplot(high_acc_city, log_scale=True)

# %%
sns.histplot(low_acc_city, log_scale=True)

# %%
city_by_acc[city_by_acc==1]
# Out:
# District 14                  1
# Virginia State University    1
# Princeville                  1
# Custer Park                  1
# Weinert                      1
#                             ..
# Elkville                     1
# Farragut                     1
# Rugby                        1
# Gatesville                   1
# Buckfield                    1
# Name: City, Length: 1306, dtype: int64

# %% [markdown]
# ### start time

# %%
df.Start_Time=pd.to_datetime(df.Start_Time)
df.Start_Time.dt.hour
# Out:
# 0           8
# 1          17
# 2          21
# 3          16
# 4          17
#            ..
# 2906605     8
# 2906606     2
# 2906607    12
# 2906608    22
# 2906609    13
# Name: Start_Time, Length: 2906610, dtype: int64

# %% [markdown]
# What time of the day are accidents happening most

# %%
sns.distplot(df.Start_Time.dt.hour, bins=24, norm_hist=True, kde=False)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# Which days of the week have more accidents

# %%
sns.distplot(df.Start_Time.dt.dayofweek, bins=7, norm_hist=True, kde=False)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# for sundays

# %%
sundays=df.Start_Time[df.Start_Time.dt.dayofweek==6]
sns.distplot(sundays.dt.hour, bins=24, norm_hist=True, kde=False)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# trends for sunday show more accidents during the afternoon unlike on the weekdays

# %% [markdown]
# for mondays

# %%
sundays=df.Start_Time[df.Start_Time.dt.dayofweek==0]
sns.distplot(sundays.dt.hour, bins=24, norm_hist=True, kde=False)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# trend through the months

# %%
sns.distplot(df.Start_Time.dt.month, bins=12, norm_hist=True, kde=False)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
df_2019= df[df.Start_Time.dt.year== 2016]
sns.distplot(df_2019.Start_Time.dt.month, bins=12, kde=False, norm_hist=True)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# We see missing values in 2016 entries(maybe even 2017 and other years), whereas 2019 is more balanced

# %% [markdown]
# ### start latitude and longilongitude

# %%
df.Start_Lat
df.Start_Lng
# Out:
# 0          -82.269157
# 1          -80.745560
# 2         -121.985052
# 3         -119.773781
# 4          -80.265091
#               ...
# 2906605    -95.399437
# 2906606   -117.342010
# 2906607    -80.335556
# 2906608   -111.952460
# 2906609   -104.748161
# Name: Start_Lng, Length: 2906610, dtype: float64

# %%
sample_df= df.sample(int(0.1*len(df)))
sns.scatterplot(x= sample_df.Start_Lng, y= sample_df.Start_Lat, size=0.001)

# %% [markdown]
# More density along the coasts, valid because these areas are more populus and hence traffic is higher and number of accidents in turn is higher.

# %%
import folium
from folium.plugins import HeatMap

# %%
for x in df[['Start_Lat','Start_Lng']].sample(100).iteritems():
  print(x.Start_Lat, x)
# Out:
# ('Start_Lat', 1996579    29.695789
# 290922     40.579640
# 2135926    31.775595
# 1168263    40.753301
# 2591816    43.129311
#              ...
# 1324782    29.699950
# 298184     42.405040
# 2238799    41.583300
# 1519865    40.080500
# 535807     38.167520
# Name: Start_Lat, Length: 100, dtype: float64)
# ('Start_Lng', 1996579    -95.426331
# 290922     -79.569810
# 2135926   -106.473457
# 1168263    -74.210833
# 2591816    -77.524956
#               ...
# 1324782    -82.180800
# 298184     -83.135510
# 2238799    -87.733360
# 1519865    -76.347950
# 535807    -122.202990
# Name: Start_Lng, Length: 100, dtype: float64)

# %%
sample_df= df.sample(int(0.001* len(df)))
lst=list(zip(list(sample_df.Start_Lat), list(sample_df.Start_Lng)))

# %%
map= folium.Map()
HeatMap(lst).add_to(map)
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%3Cscript%3EL_PREFER_CANVAS%3Dfalse%3B%20L_NO_TOUCH%3Dfalse%3B%20L_DISABLE_3D%3Dfalse%3B%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.4.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.co
# ...

# %% [markdown]
# Possibility that the sample left out the middle state's data is possible and should be considered

# %% [markdown]
# ## Questions that arise
# 1. Are there more in warmer regions than colder?
# 2. Which are the top 5 states with highest number of accident and what about their per capita
# 3. Why is the accident count for New York not showing up in the list
# 4. Among the top 100 states which are the states that appear to be the highest
# 5. What time are accidents happening most
# 6. which days of the week have more accidents
# 7. Which months have more accidents
# 8. What does the trends year on year look like
# 9. is the distridistribution of accidents by hour same on weekend

# %% [markdown]
# ## Insights
# 1. Data for New york is not provided in the dataset
# 2. Less than 5% of the cities are high acciedent regions, whereas about 95% of the cities fall into low accident regions
# 3. over 1200 cities reported only one accident (need to invesinvestigate)
# 4. The number of accidents per city decreases exponentially
# 5. Most accidents happen between 6am to 10am. Again 3pm to 6pm. maybe cause people in hurry to get to work and later going back home. Because traffic is higher during these times.
# 6. On weekends the number of accidents are lower, maybe traffic is lesser
# 7. Most of the accidents are concentrated on the coastal regions, this is valid as these regions have higher populations.
